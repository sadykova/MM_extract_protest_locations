# %% [markdown]
# ## Date March 2021
# ## Project: Mass Mobilizations dataset - Extracting protest locations names
# ## Author: Almira Sadykova-DuMond

# %%
#Importing libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
import pickle
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\16073\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
path ="C:/Users/16073/Desktop/MM" #setting the path to the new directory
os.chdir(path) # changing the directory
os.getcwd() # getting the changed directory
# Out:
# 'C:\\Users\\16073\\Desktop\\MM'

# %%
mm = pd.read_csv('geocodeMM_csv.csv')
print(mm)
# Out:
#                id           country  ccode  year         region  protest  \
# 0       201990001            Canada     20  1990  North America        1
# 1       201990002            Canada     20  1990  North America        1
# 2       201990003            Canada     20  1990  North America        1
# 3       201990004            Canada     20  1990  North America        1
# 4       201990005            Canada     20  1990  North America        1
# ...           ...               ...    ...   ...            ...      ...
# 17140  9102017002  Papua New Guinea    910  2017        Oceania        1
# 17141  9102017003  Papua New Guinea    910  2017        Oceania        1
# 17142  9102018000  Papua New Guinea    910  2018        Oceania        0
# 17143  9102019000  Papua New Guinea    910  2019        Oceania        0
# 17144  9102020000  Papua New Guinea    910  2020        Oceania        0
#
#        protestnumber  startday  startmonth  startyear  ...  protesterdemand4  \
# ...

# %%
print(mm)
# Out:
#                id           country  ccode  year         region  protest  \
# 0       201990001            Canada     20  1990  North America        1
# 1       201990002            Canada     20  1990  North America        1
# 2       201990003            Canada     20  1990  North America        1
# 3       201990004            Canada     20  1990  North America        1
# 4       201990005            Canada     20  1990  North America        1
# ...           ...               ...    ...   ...            ...      ...
# 17140  9102017002  Papua New Guinea    910  2017        Oceania        1
# 17141  9102017003  Papua New Guinea    910  2017        Oceania        1
# 17142  9102018000  Papua New Guinea    910  2018        Oceania        0
# 17143  9102019000  Papua New Guinea    910  2019        Oceania        0
# 17144  9102020000  Papua New Guinea    910  2020        Oceania        0
#
#        protestnumber  startday  startmonth  startyear  ...  protesterdemand4  \
# ...

# %%
f=mm["location"].apply(str)
iter_results=[]
for line in f:
    sentences = nltk.sent_tokenize(line)
    tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
    tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
    chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)
    
    entities=[]
    for tree in chunked_sentences:
         entities.extend(extract_entity_names(tree))  
         print(entities)
    iter_results.append(entities)
# Out:
# []
# ['Montreal', 'Quebec']
# ['Montreal', 'Quebec']
# ['Montreal', 'Quebec']
# ['Montreal', 'Quebec']
# ['Kahnawake Reservation', 'Montreal', 'Quebec']
# []
# []
# ['Toronto']
# ['Ottawa']
# ['Clayoquot Sound', 'British Columbia']
# ['Ottawa']
# ['Ottawa']
# ['Ontario']
# ['Ipperwash Provincial Park', 'Ontario']
# ['Toronto', 'Ontario']
# ['Ontario']
# []
# []
# []
# ['Quebec City', 'Quebec']
# ['Saskatoon', 'Saskatchewan']
# ['Edmonton', 'Alberta']
# ['Toronto', 'Ontario']
# []
# []
# ['Shippagan', 'New Brunswick']
# []
# ['Quebec']
# ['Toronto', 'Ontario']
# ['Caledonia', 'Ontario']
# []
# ['Montreal', 'Quebec']
# ['Toronto', 'Ontario']
# ['Montreal', 'Quebec']
# ['Vancouver', 'British Columbia']
# ['Montreal', 'Quebec']
# ['Quebec']
# []
# []
# ['Whitby']
# ['Parliament Hill', 'Ottowa']
# ['Montreal Pierre Elliot Trudeau International Airport']
# ['Toronto', 'Ontario']
# ['Toronto', 'Ontario']
# ['Toronto', 'Ontario']
# ['Queen', 'Park', 'Toronto']
# ['Toronto']
# ['Toronto']
# ...

# %%
iter_results
# Out:
# [[],
#  ['Montreal', 'Quebec'],
#  ['Montreal', 'Quebec'],
#  ['Montreal', 'Quebec'],
#  ['Montreal', 'Quebec'],
#  ['Kahnawake Reservation', 'Montreal', 'Quebec'],
#  [],
#  [],
#  ['Toronto'],
#  ['Ottawa'],
#  ['Clayoquot Sound', 'British Columbia'],
#  ['Ottawa'],
#  ['Ottawa'],
#  ['Ontario'],
#  ['Ipperwash Provincial Park', 'Ontario'],
#  ['Toronto', 'Ontario'],
#  ['Ontario'],
#  [],
#  [],
#  [],
#  ['Quebec City', 'Quebec'],
#  ['Saskatoon', 'Saskatchewan'],
#  ['Edmonton', 'Alberta'],
#  ['Toronto', 'Ontario'],
#  [],
#  [],
#  ['Shippagan', 'New Brunswick'],
#  [],
#  ['Quebec'],
#  ['Toronto', 'Ontario'],
#  ['Caledonia', 'Ontario'],
#  [],
#  ['Montreal', 'Quebec'],
#  ['Toronto', 'Ontario'],
#  ['Montreal', 'Quebec'],
#  ['Vancouver', 'British Columbia'],
#  ['Montreal', 'Quebec'],
#  ['Quebec'],
#  [],
#  [],
#  ['Whitby'],
#  ['Parliament Hill', 'Ottowa'],
#  ['Montreal Pierre Elliot Trudeau International Airport'],
#  ['Toronto', 'Ontario'],
# ...

# %%
mm["entities"]=iter_results

# %%
print(mm)
# Out:
#                id           country  ccode  year         region  protest  \
# 0       201990001            Canada     20  1990  North America        1
# 1       201990002            Canada     20  1990  North America        1
# 2       201990003            Canada     20  1990  North America        1
# 3       201990004            Canada     20  1990  North America        1
# 4       201990005            Canada     20  1990  North America        1
# ...           ...               ...    ...   ...            ...      ...
# 17140  9102017002  Papua New Guinea    910  2017        Oceania        1
# 17141  9102017003  Papua New Guinea    910  2017        Oceania        1
# 17142  9102018000  Papua New Guinea    910  2018        Oceania        0
# 17143  9102019000  Papua New Guinea    910  2019        Oceania        0
# 17144  9102020000  Papua New Guinea    910  2020        Oceania        0
#
#        protestnumber  startday  startmonth  startyear  ...   stateresponse1  \
# ...

# %%
mm.to_csv('mm_entities.csv', index=False)
